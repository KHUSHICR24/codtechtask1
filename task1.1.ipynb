# %%
import pandas as pd

# Define the data
data = {
    "Passenger ID": range(1, 21),
    "Name": [
        "John Smith", "Jane Doe", "Alice Johnson", "Bob Brown", "Carol White",
        "David Green", "Emma Wilson", "Frank Harris", "Grace Martin", "Henry Thompson",
        "Iris Lee", "Jack Robinson", "Kelly Adams", "Liam Scott", "Mia Clark",
        "Noah Lewis", "Olivia Hall", "Paul Young", "Quinn Martinez", "Ryan Thompson"
    ],
    "Age": [34, 28, 45, 50, 22, 37, 29, 40, 31, 26,
            54, 41, 30, 36, 27, 32, 25, 48, 39, 43],
    "Gender": ["Male", "Female", "Female", "Male", "Female",
               "Male", "Female", "Male", "Female", "Male",
               "Female", "Male", "Female", "Male", "Female",
               "Male", "Female", "Male", "Female", "Male",],
    "Flight Number": [
        "AA123", "UA456", "DL789", "SW321", "AA654",
        "UA987", "DL654", "SW852", "AA321", "UA654",
        "DL789", "SW321", "AA987", "UA456", "DL321",
        "SW654", "AA123", "UA789", "DL456", "SW987"
    ],
    "Origin": [
        "New York", "Chicago", "San Francisco", "Dallas", "Miami",
        "Atlanta", "Seattle", "Denver", "Los Angeles", "New York",
        "Boston", "Chicago", "Miami", "Denver", "Los Angeles",
        "Atlanta", "San Francisco", "New York", "Chicago", "Boston"
    ],
    "Destination": [
        "Los Angeles", "Miami", "New York", "Denver", "Seattle",
        "Boston", "Chicago", "Miami", "Dallas", "San Francisco",
        "Seattle", "Atlanta", "New York", "Boston", "Chicago",
        "Miami", "Dallas", "Seattle", "Denver", "New York",
    ],
    "Class": [
        "Economy", "Business", "First Class", "Economy", "Economy",
        "Business", "Economy", "First Class", "Economy", "Business",
        "Economy", "First Class", "Economy", "Business", "Economy",
        "First Class", "Economy", "Business", "Economy", "First Class"
    ],
    "Seat Number": [
        "12A", "3B", "1C", "14D", "16E",
        "2A", "10F", "1A", "15B", "2C",
        "17A", "1B", "12C", "2D", "15E",
        "1D", "12B", "3C", "16A", "1E"
    ],
    "Meal Preference": [
        "Vegetarian", "Non-Vegetarian", "Vegan", "Gluten-Free", "Non-Vegetarian",
        "Vegetarian", "Vegan", "Gluten-Free", "Non-Vegetarian", "Vegan",
        "Non-Vegetarian", "Vegetarian", "Gluten-Free", "Vegan", "Non-Vegetarian",
        "Vegetarian", "Gluten-Free", "Vegan", "Non-Vegetarian", "Vegetarian"
    ],
    "Frequent Flyer Status": [
        "Yes", "No", "Yes", "No", "No",
        "Yes", "No", "Yes", "No", "Yes",
        "No", "Yes", "No", "Yes", "No",
        "Yes", "No", "Yes", "No", "Yes",
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)

# Optionally, save it to a CSV file
df.to_csv('airline_passengers.csv', index=False)
# Out:
#     Passenger ID            Name  Age  Gender Flight Number         Origin  \
# 0              1      John Smith   34    Male         AA123       New York
# 1              2        Jane Doe   28  Female         UA456        Chicago
# 2              3   Alice Johnson   45  Female         DL789  San Francisco
# 3              4       Bob Brown   50    Male         SW321         Dallas
# 4              5     Carol White   22  Female         AA654          Miami
# 5              6     David Green   37    Male         UA987        Atlanta
# 6              7     Emma Wilson   29  Female         DL654        Seattle
# 7              8    Frank Harris   40    Male         SW852         Denver
# 8              9    Grace Martin   31  Female         AA321    Los Angeles
# 9             10  Henry Thompson   26    Male         UA654       New York
# 10            11        Iris Lee   54  Female         DL789         Boston
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'], bins=10, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
import numpy as np
mean_age = np.mean(df['Age'])
median_age = np.median(df['Age'])
std_age = np.std(df['Age'])
print(f"Mean Age: {mean_age:.2f}")
print(f"Median Age: {median_age:.2f}")
print(f"Standard Deviation of Age: {std_age:.2f}")
# Out:
# Mean Age: 35.85
# Median Age: 35.00
# Standard Deviation of Age: 8.77

# %%
age_grouped = df.groupby('Class')['Age'].mean()
print(age_grouped)
# Out:
# Class
# Business       35.0
# Economy        34.1
# First Class    40.2
# Name: Age, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'], bins=10, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(df['Age'], vert=False)
plt.title('Box Plot of Age')
plt.xlabel('Age')
plt.show()

# %%
plt.scatter(df['Age'], df['Flight Number'], color='blue')
plt.title('Age vs. Flight Number')
plt.xlabel('Age')
plt.ylabel('Flight Number')
plt.show()

# %%
import seaborn as sns
sns.pairplot(df)
plt.show()

# %%
sns.countplot(x='Class', data=df, palette='Set2')
plt.title('Count of Passengers by Class')
plt.show()
# Out:
# /var/folders/jw/1qd9f76d1pv4t94p76ppp8s40000gn/T/ipykernel_3490/3336009235.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Class', data=df, palette='Set2')

# %%
sns.violinplot(x='Class', y='Age', data=df, palette='muted')
plt.title('Age Distribution by Class')
plt.show()
# Out:
# /var/folders/jw/1qd9f76d1pv4t94p76ppp8s40000gn/T/ipykernel_3490/3719092881.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Class', y='Age', data=df, palette='muted')

# %%
# Convert 'Class' to categorical codes for correlation calculation
df['Class'] = df['Class'].astype('category').cat.codes

# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=[np.number])

# Calculate the correlation matrix
corr_matrix = numeric_df.corr()

# Create a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
